# %%
import pandas as pd

# %%
df = pd.read_csv("links.csv",delimiter="\t")

# %%
df.fillna("UNK",inplace = True)
df.head()
# Out:
#    uid                                                url  rating     tags
# 0    0                                                UNK     0.0      UNK
# 1    1  http://leetmore.ctf.su/wp/awesomecorp-secured-...     0.0      x86
# 2    2                     http://insight-labs.org/?p=368     0.0  openvms
# 3    3                        http://eindbazen.net/?p=528     0.0     xtea
# 4    4  http://blog.squareroots.de/en/2012/01/mozillac...     0.0      php

# %%
count=0
for x in df.url.str.contains("web"):
    if x:
        count+=1 
count
# Out:
# 897

# %%
df.groupby("tags")[["uid"]].count().sort_values('uid', ascending=False)
# Out:
#                       uid
# tags
# UNK                  8392
# web                   668
# pwn                   422
# crypto                396
# forensics             291
# misc                  237
# python                163
# reverse               112
# sqli                   94
# reversing              89
# engineering            66
# steganography          58
# reverse engineering    55
# recon                  44
# rev                    44
# cryptography           43
# pwnable                40
# exploit                40
# re                     40
# php                    39
# rsa                    35
# pwntools               32
# xor                    31
# stego                  31
# pcap                   30
# stegano                30
# bash                   28
# programming            27
# trivia                 26
# javascript             25
# ...                   ...
# jordan                  1
# jump                    1
# kernel-module           1
# ...
